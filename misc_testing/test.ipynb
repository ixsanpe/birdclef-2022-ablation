# %%
# %load_ext autoreload 
# %autoreload 2

from modules import SpecDataset

# %%
import pandas as pd 
import json 
DATA_PATH = 'birdclef-2022/'
metadata = pd.read_csv(f'{DATA_PATH}train_metadata.csv')# [:4000]

with open(f'{DATA_PATH}all_birds.json') as f:
    birds = json.load(f)

# %%
print(len(birds))
# Out:
# 152

# %%
from decouple import config 
dataset = SpecDataset(metadata, config('SPEC_PATH'), labels=birds)

# %%
print(config('SPEC_PATH'))
print(dataset[100][0].shape)
# Out:
# output/data/spec/
# torch.Size([64, 2903])

# %%
from matplotlib import  pyplot as plt  
idx = 3
plt.imshow(dataset[idx][0][:, :128])
